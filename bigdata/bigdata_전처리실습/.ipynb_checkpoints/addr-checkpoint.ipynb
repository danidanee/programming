# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('data/도로명코드.csv', index_col=0, header=None)
df
# Out:
#                    1                        2   3        4        5     6   \
# 0
# 111102005001     세종대로             Sejong-daero   0    서울특별시    Seoul   종로구
# 111102005001     세종대로             Sejong-daero   1    서울특별시    Seoul   종로구
# 111102005001     세종대로             Sejong-daero   2    서울특별시    Seoul   종로구
# 111102100001     삼일대로              Samil-daero   0    서울특별시    Seoul   종로구
# 111102100001     삼일대로              Samil-daero   1    서울특별시    Seoul   종로구
# ...               ...                      ...  ..      ...      ...   ...
# 501304857888     상천1길          Sangcheon 1-gil   1  제주특별자치도  Jeju-do  서귀포시
# 501304857897  풍천로38번길  Pungcheon-ro 38beon-gil   0  제주특별자치도  Jeju-do  서귀포시
# 501304857897  풍천로38번길  Pungcheon-ro 38beon-gil   1  제주특별자치도  Jeju-do  서귀포시
# 501304857899    태흥샘못길      Taeheungsaemmot-gil   0  제주특별자치도  Jeju-do  서귀포시
# 501304857899    태흥샘못길      Taeheungsaemmot-gil   1  제주특별자치도  Jeju-do  서귀포시
#
#                        7     8                9   10     11  12
# ...

# %%
df = df.iloc[:, [0,2,3]]
df
# Out:
#                     1  3        4
# 0
# 111102005001     세종대로  0    서울특별시
# 111102005001     세종대로  1    서울특별시
# 111102005001     세종대로  2    서울특별시
# 111102100001     삼일대로  0    서울특별시
# 111102100001     삼일대로  1    서울특별시
# ...               ... ..      ...
# 501304857888     상천1길  1  제주특별자치도
# 501304857897  풍천로38번길  0  제주특별자치도
# 501304857897  풍천로38번길  1  제주특별자치도
# 501304857899    태흥샘못길  0  제주특별자치도
# 501304857899    태흥샘못길  1  제주특별자치도
#
# [359358 rows x 3 columns]

# %%
boolean = df[4] == '서울특별시'
df = df.loc[boolean]
df
# Out:
#                    1  3      4
# 0
# 111102005001    세종대로  0  서울특별시
# 111102005001    세종대로  1  서울특별시
# 111102005001    세종대로  2  서울특별시
# 111102100001    삼일대로  0  서울특별시
# 111102100001    삼일대로  1  서울특별시
# ...              ... ..    ...
# 117404172445  상일로10길  0  서울특별시
# 117404172445  상일로10길  1  서울특별시
# 117404172446  상일로12길  0  서울특별시
# 117404172446  상일로12길  1  서울특별시
# 117404172446  상일로12길  2  서울특별시
#
# [31193 rows x 3 columns]

# %%
df.columns=['도로명코드','도로명','읍면동일련번호','시도명']
# Out:
# c:\users\82107\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df
# Out:
#                    1  3      4
# 0
# 111102005001    세종대로  0  서울특별시
# 111102005001    세종대로  1  서울특별시
# 111102005001    세종대로  2  서울특별시
# 111102100001    삼일대로  0  서울특별시
# 111102100001    삼일대로  1  서울특별시
# ...              ... ..    ...
# 117404172445  상일로10길  0  서울특별시
# 117404172445  상일로10길  1  서울특별시
# 117404172446  상일로12길  0  서울특별시
# 117404172446  상일로12길  1  서울특별시
# 117404172446  상일로12길  2  서울특별시
#
# [31193 rows x 3 columns]
